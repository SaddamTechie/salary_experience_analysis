# %%
# Load and Explore Data

# %%
import pandas as pd
import matplotlib.pyplot as plt

filename = 'Employee_Salary_Dataset.csv'

data = pd.read_csv(filename)

print(data.head())
# Out:
#    ID  Experience_Years  Age  Gender  Salary
# 0   1                 5   28  Female  250000
# 1   2                 1   21    Male   50000
# 2   3                 3   23  Female  170000
# 3   4                 2   22    Male   25000
# 4   5                 1   17    Male   10000

# %%
print(data.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35 entries, 0 to 34
# Data columns (total 5 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   ID                35 non-null     int64
#  1   Experience_Years  35 non-null     int64
#  2   Age               35 non-null     int64
#  3   Gender            35 non-null     object
#  4   Salary            35 non-null     int64
# dtypes: int64(4), object(1)
# memory usage: 1.5+ KB
# None

# %%
missing_values = data.isnull().sum()
print(missing_values)
# Out:
# ID                  0
# Experience_Years    0
# Age                 0
# Gender              0
# Salary              0
# dtype: int64

# %%
# Basic Data analysis

# %%
data.describe()
# Out:
#               ID  Experience_Years        Age        Salary
# count  35.000000          35.00000  35.000000  3.500000e+01
# mean   18.000000           9.20000  35.485714  2.059147e+06
# std    10.246951           7.55295  14.643552  3.170124e+06
# min     1.000000           1.00000  17.000000  3.000000e+03
# 25%     9.500000           2.50000  22.500000  2.250000e+04
# 50%    18.000000           6.00000  29.000000  2.500000e+05
# 75%    26.500000          15.00000  53.500000  3.270000e+06
# max    35.000000          27.00000  62.000000  1.000000e+07

# %%
mean_salary_by_experience = data.groupby('Salary')['Experience_Years'].mean().sort_values(ascending=True)
print(mean_salary_by_experience)
# Out:
# Salary
# 3000         1.0
# 6000         1.0
# 10000        1.0
# 50000        1.0
# 6100         2.0
# 7500         2.0
# 9000         2.0
# 15000        2.0
# 20000        3.0
# 25000        3.0
# 170000       3.0
# 8900         4.0
# 87000        4.0
# 250000       4.5
# 6845000      5.0
# 1400000      6.0
# 61500       10.0
# 330000      10.0
# 930000      10.0
# 80000       10.0
# 220100      11.0
# 6000050     14.0
# 650000      15.0
# 900000      15.0
# 7900000     15.0
# 6570000     15.0
# 7600000     16.0
# 9300000     19.0
# 800000      19.0
# 5000000     19.0
# 1540000     20.0
# 5001000     25.0
# 10000000    27.0
# Name: Experience_Years, dtype: float64

# %%
# Data Visualization

# %%
# Plotting the line chart
plt.figure(figsize=(10,6))
plt.plot(mean_salary_by_experience.index, mean_salary_by_experience.values, marker='o')
plt.title('Average Salary by Years of Experience')
plt.xlabel('Years of Experience')
plt.ylabel('Average Salary ($)')
plt.grid(True)
plt.xticks(mean_salary_by_experience.index) # Set x-ticks to be the years of experience
plt.show()

# %%
# Plotting the bar chart
plt.figure(figsize=(10,6))
mean_salary_by_experience.plot(kind='bar', color='skyblue', edgecolor='black')

# Adding titles and labels
plt.title('Average Salary by Years of Experience', fontsize=16)
plt.xlabel('Years of Experience', fontsize=12)
plt.ylabel('Average Salary ($)', fontsize=12)
plt.xticks(rotation=0) # Rotate x-ticks for better readability
plt.grid(axis='y', linestyle='--', alpha=0.7)

# %%
# Plotting the histogram for the 'Salary' column
plt.figure(figsize=(10,6))
data['Salary'].hist(bins=30, color='skyblue', edgecolor='black')

# Adding titles and labels
plt.title('Histogram of Salary Distribution', fontsize=16)
plt.xlabel('Salary ($)', fontsize=12)
plt.ylabel('Frequency', fontsize=12)
plt.grid(axis='y', linestyle='--', alpha=0.7)

# Show the plot
plt.show()

# %%
data.plot.scatter(x='Experience_Years', y='Salary', s=100, c='blue', alpha=0.5)

# Adding titles and labels
plt.title('Scatter Plot of Salary vs. Experience Years', fontsize=16)
plt.xlabel('Years of Experience', fontsize=12)
plt.ylabel('Salary ($)', fontsize=12)
plt.grid(True)

# Show the plot
plt.show()
